# %%
import sklearn as sk
import matplotlib as plt
import pandas as pd


# Use read_csv() to load the CSV file into a pandas DataFrame
data = pd.read_csv('Data/full_data.csv',low_memory=False)
data
# Out:
#        Unnamed: 0 lastTradeDate  strike   price     bid     ask    change  \
# 0               0    2024-03-08   210.0  199.70  417.49  418.06  0.000000
# 1               1    2024-03-27   220.0  200.32  417.49  418.06 -9.569992
# 2               2    2024-03-27   230.0  189.90  417.49  418.06  1.399994
# 3               3    2024-02-13   235.0  174.91  417.49  418.06  0.000000
# 4               4    2024-03-27   250.0  170.23  417.49  418.06 -9.120010
# ...           ...           ...     ...     ...     ...     ...       ...
# 73149       73561    2024-01-10     2.0    0.05    1.71    2.34  0.000000
# 73150       73562    2023-11-16     3.0    0.15    1.71    2.34  0.000000
# 73151       73563    2023-09-19     4.0    0.16    1.71    2.34  0.000000
# 73152       73564    2023-12-06     1.0    0.25    1.71    2.34  0.000000
# 73153       73565    2023-12-04     2.0    1.20    1.71    2.34  0.000000
#
#        percentChange      volume  openInterest  ...  returnOnAssets  \
# 0           0.000000  19275689.0           0.0  ...         0.15190
# 1          -4.559527  19275689.0           2.0  ...         0.15190
# 2           0.742702  19275689.0           3.0  ...         0.15190
# 3           0.000000  19275689.0           6.0  ...         0.15190
# 4          -5.085035  19275689.0           6.0  ...         0.15190
# ...              ...         ...           ...  ...             ...
# 73149       0.000000    124821.0        1382.0  ...        -0.10972
# 73150       0.000000    124821.0          12.0  ...        -0.10972
# 73151       0.000000    124821.0           1.0  ...        -0.10972
# 73152       0.000000    124821.0           1.0  ...        -0.10972
# 73153       0.000000    124821.0          15.0  ...        -0.10972
#
#       returnOnEquity  freeCashflow  operatingCashflow revenueGrowth  \
# 0            0.39174  5.868100e+10       1.026470e+11         0.176
# 1            0.39174  5.868100e+10       1.026470e+11         0.176
# 2            0.39174  5.868100e+10       1.026470e+11         0.176
# 3            0.39174  5.868100e+10       1.026470e+11         0.176
# 4            0.39174  5.868100e+10       1.026470e+11         0.176
# ...              ...           ...                ...           ...
# 73149        0.10401  2.431477e+08       5.283660e+08        -0.425
# 73150        0.10401  2.431477e+08       5.283660e+08        -0.425
# 73151        0.10401  2.431477e+08       5.283660e+08        -0.425
# 73152        0.10401  2.431477e+08       5.283660e+08        -0.425
# 73153        0.10401  2.431477e+08       5.283660e+08        -0.425
#
#        grossMargins ebitdaMargins operatingMargins       tau      tau2
# 0           0.69815       0.52037          0.43586  0.055556  0.054795
# 1           0.69815       0.52037          0.43586  0.003968  0.002740
# 2           0.69815       0.52037          0.43586  0.003968  0.002740
# 3           0.69815       0.52037          0.43586  0.126984  0.120548
# 4           0.69815       0.52037          0.43586  0.003968  0.002740
# ...             ...           ...              ...       ...       ...
# 73149       0.03447      -0.18544         -0.18645  0.365079  0.350685
# 73150       0.03447      -0.18544         -0.18645  0.519841  0.501370
# 73151       0.03447      -0.18544         -0.18645  0.686508  0.660274
# 73152       0.03447      -0.18544         -0.18645  0.464286  0.446575
# 73153       0.03447      -0.18544         -0.18645  0.472222  0.452055
#
# [73154 rows x 115 columns]

# %%
tickers_symbol = data.ticker.unique().tolist()

# %%
import random

tickers_symbol = random.sample(tickers_symbol, 200)

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime


data = pd.DataFrame()  # Initialize an empty DataFrame


for ticker_symbol in tickers_symbol:
    try:
        ticker = yf.Ticker(ticker_symbol)
        option_chain = ticker.option_chain()
        try:
            ticker_calls = option_chain.calls  # Extract calls data
            ticker_calls['ticker'] = ticker_symbol  # Add a column for ticker symbol
            ticker_calls['call'] = 1 # Add a column for ticker symbol
            data = pd.concat([data, ticker_calls])  # Concatenate calls data to the DataFrame
        except:
            pass
        
        try:
            ticker_puts = option_chain.puts  # Extract puts data
            ticker_puts['ticker'] = ticker_symbol  # Add a column for ticker symbol
            ticker_puts['call'] = 0 # Add a column for ticker symbol
            data = pd.concat([data, ticker_puts])  # Concatenate puts data to the DataFrame
        except:
            pass
    except:
        pass
data
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0    MCW240719C00007500 2024-06-25 14:10:02+00:00     7.5       0.40  0.00
# 0    MCW240719P00007500 2024-07-01 19:02:39+00:00     7.5       0.85  0.45
# 0   LFVN240719C00007500 2024-06-26 15:25:32+00:00     7.5       0.05  0.00
# 0   BRCC240719C00001000 2024-05-09 15:28:40+00:00     1.0       4.34  4.80
# 1   BRCC240719C00002000 2024-05-24 17:18:14+00:00     2.0       3.68  4.20
# ..                  ...                       ...     ...        ...   ...
# 7    WMG240719P00034000 2024-06-21 17:27:21+00:00    34.0       3.70  1.55
# 8    WMG240719P00035000 2024-05-08 16:54:52+00:00    35.0       1.60  3.60
# 9    WMG240719P00036000 2024-05-08 16:57:53+00:00    36.0       2.10  4.10
# 10   WMG240719P00037000 2024-05-28 14:58:55+00:00    37.0       6.78  4.50
# 11   WMG240719P00045000 2024-01-25 17:38:16+00:00    45.0       9.00  8.70
#
#       ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0    0.30     0.0            0.0     1.0          32.0           0.765627
# 0    0.90     0.0            0.0    14.0          14.0           0.964844
# 0    0.75     0.0            0.0     NaN          50.0           2.113286
# 0    5.30     0.0            0.0    10.0           0.0           4.250005
# 1    5.20     0.0            0.0     1.0           3.0           8.679692
# ..    ...     ...            ...     ...           ...                ...
# 7    5.30     0.0            0.0     1.0          27.0           1.341800
# 8    8.00     0.0            0.0     4.0           0.0           1.215824
# 9    8.90     0.0            0.0    12.0           0.0           1.160160
# 10   8.40     0.0            0.0     1.0           1.0           1.753907
# 11  13.00     0.0            0.0     NaN           0.0           0.000010
#
#    inTheMoney contractSize currency ticker  call
# 0         0.0      REGULAR      USD    MCW     1
# 0         1.0      REGULAR      USD    MCW     0
# 0         0.0      REGULAR      USD   LFVN     1
# 0        True      REGULAR      USD   BRCC     1
# 1        True      REGULAR      USD   BRCC     1
# ..        ...          ...      ...    ...   ...
# 7        True      REGULAR      USD    WMG     0
# 8        True      REGULAR      USD    WMG     0
# 9        True      REGULAR      USD    WMG     0
# 10       True      REGULAR      USD    WMG     0
# 11       True      REGULAR      USD    WMG     0
#
# [3270 rows x 16 columns]

# %%
from datetime import datetime


def extract_expiration(row):
    index = len(row['ticker'])
    expiration_str = row['contractSymbol']
    try:
        expiration_date = datetime.strptime(expiration_str[index: index + 6], "%y%m%d").date()
    except:
        expiration_date = None
    return expiration_date

# Apply function to each row
data['expirationDate'] = data.apply(extract_expiration, axis=1)
data
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0    MCW240719C00007500 2024-06-25 14:10:02+00:00     7.5       0.40  0.00
# 0    MCW240719P00007500 2024-07-01 19:02:39+00:00     7.5       0.85  0.45
# 0   LFVN240719C00007500 2024-06-26 15:25:32+00:00     7.5       0.05  0.00
# 0   BRCC240719C00001000 2024-05-09 15:28:40+00:00     1.0       4.34  4.80
# 1   BRCC240719C00002000 2024-05-24 17:18:14+00:00     2.0       3.68  4.20
# ..                  ...                       ...     ...        ...   ...
# 7    WMG240719P00034000 2024-06-21 17:27:21+00:00    34.0       3.70  1.55
# 8    WMG240719P00035000 2024-05-08 16:54:52+00:00    35.0       1.60  3.60
# 9    WMG240719P00036000 2024-05-08 16:57:53+00:00    36.0       2.10  4.10
# 10   WMG240719P00037000 2024-05-28 14:58:55+00:00    37.0       6.78  4.50
# 11   WMG240719P00045000 2024-01-25 17:38:16+00:00    45.0       9.00  8.70
#
#       ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0    0.30     0.0            0.0     1.0          32.0           0.765627
# 0    0.90     0.0            0.0    14.0          14.0           0.964844
# 0    0.75     0.0            0.0     NaN          50.0           2.113286
# 0    5.30     0.0            0.0    10.0           0.0           4.250005
# 1    5.20     0.0            0.0     1.0           3.0           8.679692
# ..    ...     ...            ...     ...           ...                ...
# 7    5.30     0.0            0.0     1.0          27.0           1.341800
# 8    8.00     0.0            0.0     4.0           0.0           1.215824
# 9    8.90     0.0            0.0    12.0           0.0           1.160160
# 10   8.40     0.0            0.0     1.0           1.0           1.753907
# 11  13.00     0.0            0.0     NaN           0.0           0.000010
#
#    inTheMoney contractSize currency ticker  call expirationDate
# 0         0.0      REGULAR      USD    MCW     1     2024-07-19
# 0         1.0      REGULAR      USD    MCW     0     2024-07-19
# 0         0.0      REGULAR      USD   LFVN     1     2024-07-19
# 0        True      REGULAR      USD   BRCC     1     2024-07-19
# 1        True      REGULAR      USD   BRCC     1     2024-07-19
# ..        ...          ...      ...    ...   ...            ...
# 7        True      REGULAR      USD    WMG     0     2024-07-19
# 8        True      REGULAR      USD    WMG     0     2024-07-19
# 9        True      REGULAR      USD    WMG     0     2024-07-19
# 10       True      REGULAR      USD    WMG     0     2024-07-19
# 11       True      REGULAR      USD    WMG     0     2024-07-19
#
# [3270 rows x 17 columns]

# %%
def extract_data(lastTradeDate):
    data_datetime = datetime.strptime(str(lastTradeDate), "%Y-%m-%d %H:%M:%S%z")
    return data_datetime.date()

# Apply function to each row
data['lastTradeDate'] = data['lastTradeDate'].apply(extract_data)
data
# Out:
#          contractSymbol lastTradeDate  strike  lastPrice   bid    ask  change  \
# 0    MCW240719C00007500    2024-06-25     7.5       0.40  0.00   0.30     0.0
# 0    MCW240719P00007500    2024-07-01     7.5       0.85  0.45   0.90     0.0
# 0   LFVN240719C00007500    2024-06-26     7.5       0.05  0.00   0.75     0.0
# 0   BRCC240719C00001000    2024-05-09     1.0       4.34  4.80   5.30     0.0
# 1   BRCC240719C00002000    2024-05-24     2.0       3.68  4.20   5.20     0.0
# ..                  ...           ...     ...        ...   ...    ...     ...
# 7    WMG240719P00034000    2024-06-21    34.0       3.70  1.55   5.30     0.0
# 8    WMG240719P00035000    2024-05-08    35.0       1.60  3.60   8.00     0.0
# 9    WMG240719P00036000    2024-05-08    36.0       2.10  4.10   8.90     0.0
# 10   WMG240719P00037000    2024-05-28    37.0       6.78  4.50   8.40     0.0
# 11   WMG240719P00045000    2024-01-25    45.0       9.00  8.70  13.00     0.0
#
#     percentChange  volume  openInterest  impliedVolatility inTheMoney  \
# 0             0.0     1.0          32.0           0.765627        0.0
# 0             0.0    14.0          14.0           0.964844        1.0
# 0             0.0     NaN          50.0           2.113286        0.0
# 0             0.0    10.0           0.0           4.250005       True
# 1             0.0     1.0           3.0           8.679692       True
# ..            ...     ...           ...                ...        ...
# 7             0.0     1.0          27.0           1.341800       True
# 8             0.0     4.0           0.0           1.215824       True
# 9             0.0    12.0           0.0           1.160160       True
# 10            0.0     1.0           1.0           1.753907       True
# 11            0.0     NaN           0.0           0.000010       True
#
#    contractSize currency ticker  call expirationDate
# 0       REGULAR      USD    MCW     1     2024-07-19
# 0       REGULAR      USD    MCW     0     2024-07-19
# 0       REGULAR      USD   LFVN     1     2024-07-19
# 0       REGULAR      USD   BRCC     1     2024-07-19
# 1       REGULAR      USD   BRCC     1     2024-07-19
# ..          ...      ...    ...   ...            ...
# 7       REGULAR      USD    WMG     0     2024-07-19
# 8       REGULAR      USD    WMG     0     2024-07-19
# 9       REGULAR      USD    WMG     0     2024-07-19
# 10      REGULAR      USD    WMG     0     2024-07-19
# 11      REGULAR      USD    WMG     0     2024-07-19
#
# [3270 rows x 17 columns]

# %%
data.drop('contractSymbol', axis=1, inplace=True)
data.drop('currency', axis=1, inplace=True)

# %%
from datetime import datetime, timedelta
import yfinance as yf

def stock_price(row):
    end = datetime.strptime(str(row['lastTradeDate']), "%Y-%m-%d") + timedelta(days=10)
    start = end - timedelta(days=20)

    ticker = row['ticker']
    stock = yf.Ticker(ticker)
    try:
        historical_data = stock.history(start=start, end=end)
        closest_date = historical_data.index.min()
        closest_price = round(historical_data.loc[closest_date]['Close'], 2)
    except:
        closest_price = False
    return closest_price


data['stock'] = data.apply(stock_price, axis=1)
data = data[data['stock'] != 'False']
data['stock'] = data['stock'].astype('float')

# %%
ticker_list = data['ticker'].unique()

info = {}
for ticker in ticker_list:
    company = yf.Ticker(ticker)
    company_info = company.info
    
    # Delete unwanted keys
    keys_to_remove = ['phone', 'website', 'longBusinessSummary', 'companyOfficers', 
                      'currency', 'symbol', 'underlyingSymbol', 'shortName', 
                      'longName', 'financialCurrency']
    for key in keys_to_remove:
        company_info.pop(key, None)
    
    info[ticker] = company_info  # Use the ticker symbol as the key

for index, row in data.iterrows():
    ticker = row['ticker']
    company_info = info.get(ticker)  # Retrieve company information using ticker symbol
    if company_info:
        for key, value in company_info.items():
            data.loc[index, key] = value  # Assign company information to DataFrame
# Out:
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\3963108710.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[index, key] = value  # Assign company information to DataFrame

# %%
data
# Out:
#    lastTradeDate  strike  lastPrice    bid    ask  change  percentChange  \
# 0     2024-06-18    65.0       1.45  49.23  49.93    0.00       0.000000
# 1     2023-12-20    70.0       7.00  27.96  28.01    0.00       0.000000
# 2     2024-06-04    75.0       0.20  27.96  28.01    0.00       0.000000
# 3     2024-02-22    85.0       0.45  27.96  28.01    0.00       0.000000
# 4     2024-01-26    95.0       0.10  27.96  28.01    0.00       0.000000
# ..           ...     ...        ...    ...    ...     ...            ...
# 2     2024-07-08    27.0       0.20  27.96  28.01   -0.02      -9.090907
# 3     2024-07-05    28.0       0.64  27.96  28.01    0.00       0.000000
# 4     2024-07-08    29.0       1.11  27.96  28.01   -0.19     -14.615380
# 5     2024-06-12    32.0       0.95  27.96  28.01    0.00       0.000000
# 0     2024-06-21    45.0       0.53  49.23  49.93    0.00       0.000000
#
#       volume  openInterest  impliedVolatility  ... operatingCashflow  \
# 0     4038.0           8.0           0.220223  ...       114357000.0
# 1   127321.0           0.0           1.195317  ...       387223008.0
# 2   127321.0           5.0           0.533208  ...       387223008.0
# 3   127321.0          32.0           0.867189  ...       387223008.0
# 4   127321.0           2.0           1.093755  ...       387223008.0
# ..       ...           ...                ...  ...               ...
# 2   127321.0          16.0           0.429693  ...       387223008.0
# 3   127321.0          83.0           0.367194  ...       387223008.0
# 4   127321.0          16.0           0.339850  ...       387223008.0
# 5   127321.0          15.0           0.000010  ...       387223008.0
# 0     4038.0          50.0           1.121098  ...       114357000.0
#
#    earningsGrowth revenueGrowth  grossMargins ebitdaMargins  operatingMargins  \
# 0          -0.111        -0.003        0.7008       0.04303           0.42872
# 1           4.281         0.095        0.7008       0.04303          -0.01177
# 2           4.281         0.095        0.7008       0.04303          -0.01177
# 3           4.281         0.095        0.7008       0.04303          -0.01177
# 4           4.281         0.095        0.7008       0.04303          -0.01177
# ..            ...           ...           ...           ...               ...
# 2           4.281         0.095        0.7008       0.04303          -0.01177
# 3           4.281         0.095        0.7008       0.04303          -0.01177
# 4           4.281         0.095        0.7008       0.04303          -0.01177
# 5           4.281         0.095        0.7008       0.04303          -0.01177
# 0          -0.111        -0.003        0.7008       0.04303           0.42872
#
#    trailingPegRatio           fax fiveYearAvgDividendYield    address2
# 0               NaN  801 821 2872                     2.35  Suite 1100
# 1            0.3067  801 821 2872                     3.46  Suite 1100
# 2            0.3067  801 821 2872                     3.46  Suite 1100
# 3            0.3067  801 821 2872                     3.46  Suite 1100
# 4            0.3067  801 821 2872                     3.46  Suite 1100
# ..              ...           ...                      ...         ...
# 2            0.3067  801 821 2872                     3.46  Suite 1100
# 3            0.3067  801 821 2872                     3.46  Suite 1100
# 4            0.3067  801 821 2872                     3.46  Suite 1100
# 5            0.3067  801 821 2872                     3.46  Suite 1100
# 0               NaN  801 821 2872                     2.35  Suite 1100
#
# [3554 rows x 137 columns]

# %%
missing_percentage = (data.isnull().sum() / len(data)) * 100

# Filtra solo le colonne con valori mancanti
columns_to_drop = missing_percentage[missing_percentage > 50]
data = data.drop(columns=columns_to_drop)

# %%
to_fill_0 = [
    'dividendRate',
    'dividendYield',
    'exDividendDate',
    'payoutRatio',
    'fiveYearAvgDividendYield',
    'trailingAnnualDividendRate',
    'trailingAnnualDividendYield',
    'impliedSharesOutstanding',
    'lastDividendValue',
    'lastDividendDate', 
]

data[to_fill_0] = data[to_fill_0].fillna(0)

# %%
to_fill_median =[
    'auditRisk',
    'boardRisk', 
    'compensationRisk',
    'shareHolderRightsRisk',
    'overallRisk', 
]

column_median = data[to_fill_median].median()
data[to_fill_median] = data[to_fill_median].fillna(column_median)

# %%
missing_percentage = (data.isnull().sum() / len(data)) * 100

# Filtra solo le colonne con valori mancanti
columns_to_drop = missing_percentage[missing_percentage > 0]
columns_to_drop
# Out:
# percentChange        0.028137
# openInterest         0.140687
# irWebsite            6.443444
# lastSplitFactor      6.274620
# lastSplitDate        6.274620
# trailingPegRatio    22.537985
# fax                  6.274620
# address2             7.118739
# dtype: float64

# %%
data.drop('irWebsite', axis=1, inplace=True)
data.drop('lastSplitFactor', axis=1, inplace=True)
data.drop('lastSplitDate', axis=1, inplace=True)
data.drop('trailingPegRatio', axis=1, inplace=True)
data.drop('fax', axis=1, inplace=True)
data.drop('address2', axis=1, inplace=True)

# %%
import pandas as pd
import numpy as np

# Assuming 'data' is a DataFrame containing 'lastTradeDate' and 'expirationDate' columns

def tau(row):
    try:
        start_date = pd.to_datetime(row['lastTradeDate']).to_numpy().astype('datetime64[D]')
        end_date = pd.to_datetime(row['expirationDate']).to_numpy().astype('datetime64[D]')
    except ValueError:
        return np.nan
    
    residual_days = np.busday_count(start_date, end_date)
    tau_value = residual_days / 252
    return tau_value

def tau2(row):
    try:
        start_date = pd.to_datetime(row['lastTradeDate']).to_numpy().astype('datetime64[D]')
        end_date = pd.to_datetime(row['expirationDate']).to_numpy().astype('datetime64[D]')
    except ValueError:
        return np.nan
    
    residual_days = (end_date - start_date).astype('timedelta64[D]').astype(int)
    tau_value = residual_days / 365
    return tau_value

# Assuming 'data' is your DataFrame
data['tau'] = data.apply(tau, axis=1)
data['tau2'] = data.apply(tau2, axis=1)

data.dropna(subset=['expirationDate'], inplace=True)
# Out:
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\1703936346.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['tau'] = data.apply(tau, axis=1)
# C:\Users\domen\AppData\Local\Temp\ipykernel_5356\1703936346.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['tau2'] = data.apply(tau2, axis=1)

# %%
import yfinance as yf
import numpy as np
import pandas as pd

volatility_dic = {}

for ticker in ticker_list:

    stock_data = yf.download(ticker, start='2023-03-27', end='2024-03-27')

    if 'Close' in stock_data.columns:
        stock_data['Daily Return'] = stock_data['Close'].pct_change()
        average_daily_return = stock_data['Daily Return'].mean()
        daily_volatility = stock_data['Daily Return'].std()
        annual_volatility = daily_volatility * np.sqrt(252)

        volatility_dic[ticker] = annual_volatility
    else:
        print("Error")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
from datetime import datetime, timedelta
import yfinance as yf

def volatility(row):

    ticker = row['ticker']
    return volatility_dic[ticker]


data['sigma'] = data.apply(volatility, axis=1)

# %%
to_correct = data.ticker[data.sigma.isnull()].unique()

# %%
stock_data['Daily Return'] = stock_data['Close'].pct_change()
average_daily_return = stock_data['Daily Return'].mean()
daily_volatility = stock_data['Daily Return'].std()
annual_volatility = daily_volatility * np.sqrt(252)

volatility_dic[ticker] = annual_volatility

# %%
data = data.dropna(subset=['sigma'])

# %%
data
# Out:
#        Unnamed: 0 lastTradeDate  strike   price     bid     ask    change  \
# 0               0    2024-03-08   210.0  199.70  417.49  418.06  0.000000
# 1               1    2024-03-27   220.0  200.32  417.49  418.06 -9.569992
# 2               2    2024-03-27   230.0  189.90  417.49  418.06  1.399994
# 3               3    2024-02-13   235.0  174.91  417.49  418.06  0.000000
# 4               4    2024-03-27   250.0  170.23  417.49  418.06 -9.120010
# ...           ...           ...     ...     ...     ...     ...       ...
# 73149       73561    2024-01-10     2.0    0.05    1.71    2.34  0.000000
# 73150       73562    2023-11-16     3.0    0.15    1.71    2.34  0.000000
# 73151       73563    2023-09-19     4.0    0.16    1.71    2.34  0.000000
# 73152       73564    2023-12-06     1.0    0.25    1.71    2.34  0.000000
# 73153       73565    2023-12-04     2.0    1.20    1.71    2.34  0.000000
#
#            volume     sigma inTheMoney  ... returnOnAssets  returnOnEquity  \
# 0      19275689.0  0.223118        1.0  ...        0.15190         0.39174
# 1      19275689.0  0.223118        1.0  ...        0.15190         0.39174
# 2      19275689.0  0.223118        1.0  ...        0.15190         0.39174
# 3      19275689.0  0.223118        1.0  ...        0.15190         0.39174
# 4      19275689.0  0.223118        1.0  ...        0.15190         0.39174
# ...           ...       ...        ...  ...            ...             ...
# 73149    124821.0  1.064334       True  ...       -0.10972         0.10401
# 73150    124821.0  1.064334      False  ...       -0.10972         0.10401
# 73151    124821.0  1.064334      False  ...       -0.10972         0.10401
# 73152    124821.0  1.064334      False  ...       -0.10972         0.10401
# 73153    124821.0  1.064334      False  ...       -0.10972         0.10401
#
#        freeCashflow  operatingCashflow revenueGrowth grossMargins  \
# 0      5.868100e+10       1.026470e+11         0.176      0.69815
# 1      5.868100e+10       1.026470e+11         0.176      0.69815
# 2      5.868100e+10       1.026470e+11         0.176      0.69815
# 3      5.868100e+10       1.026470e+11         0.176      0.69815
# 4      5.868100e+10       1.026470e+11         0.176      0.69815
# ...             ...                ...           ...          ...
# 73149  2.431477e+08       5.283660e+08        -0.425      0.03447
# 73150  2.431477e+08       5.283660e+08        -0.425      0.03447
# 73151  2.431477e+08       5.283660e+08        -0.425      0.03447
# 73152  2.431477e+08       5.283660e+08        -0.425      0.03447
# 73153  2.431477e+08       5.283660e+08        -0.425      0.03447
#
#       ebitdaMargins operatingMargins       tau      tau2
# 0           0.52037          0.43586  0.055556  0.054795
# 1           0.52037          0.43586  0.003968  0.002740
# 2           0.52037          0.43586  0.003968  0.002740
# 3           0.52037          0.43586  0.126984  0.120548
# 4           0.52037          0.43586  0.003968  0.002740
# ...             ...              ...       ...       ...
# 73149      -0.18544         -0.18645  0.365079  0.350685
# 73150      -0.18544         -0.18645  0.519841  0.501370
# 73151      -0.18544         -0.18645  0.686508  0.660274
# 73152      -0.18544         -0.18645  0.464286  0.446575
# 73153      -0.18544         -0.18645  0.472222  0.452055
#
# [73154 rows x 113 columns]

# %%
data.to_csv('new_data.csv', index=False)
